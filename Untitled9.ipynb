# %% [markdown]
# <a href="https://colab.research.google.com/github/TranNgocXuanThanh/cifar10-AI_W9_31_03_2023-.ipynb/blob/main/Untitled9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#from keras.utils import load_img
# import numpy as np
#img=load_img(filename, target_size=(32,32)) (chuyen size)
#img= img_to_array(img)
#img= img.reshape(1,32*32*3)
#img= img.astype('float32')
#img=img/255
#np.argmax(model.predict(img), axis=-1)

# %%
from keras.datasets import cifar10
import matplotlib.pyplot as plt
(x_train,y_train),(x_test,y_test)=cifar10.load_data() #x_train=images, y_train=label
print(x_train.shape)
print(y_train.shape)
print(x_test.shape)
print(y_test.shape)
##################################################
digit=x_train[111]
plt.imshow(digit, cmap=plt.cm.binary)
plt.show()
print("So: ",y_train[111])
##################################################
for i in range (15):
  plt.subplot(5,5,i+1)
  plt.tight_layout()
  plt.imshow(x_train[i],cmap='gray',
             interpolation='none')
  plt.title("So:{}".format(y_train[i]))
  plt.xticks([])
  plt.yticks([])
##################################################
# 4 lop
from keras.models import Sequential
from keras.layers import Dense
model = Sequential()
model.add(Dense(4000,activation='relu',
                 input_shape=(32*32*3,)))
model.add(Dense(1000,activation='relu'))
model.add(Dense(500,activation='relu'))
model.add(Dense(10,activation='softmax'))
model.summary()
##################################################
#luu bien
X=x_test
Y=y_test
##################################################
x_train=x_train.reshape(50000, 32*32*3)
#chuyen ve anh xam (chia cho 255 (so thuc)) 3 kenh ve 1 kenh
x_train=x_train.astype('float32')/255
#resize anh
x_test=x_test.reshape(10000,32*32*3)
#doi mau anh thanh den trang
x_test=x_test.astype('float32')/255
print(x_train.shape)
print(x_test.shape)
##################################################
from keras.utils import to_categorical
y_train=to_categorical(y_train,10)
y_test=to_categorical(y_test,10)
print(y_train.shape)
print(y_test.shape)
##################################################
model.compile(optimizer='rmsprop',loss='categorical_crossentropy',metrics=['accuracy'])
model.fit(x_train, y_train, epochs=10, batch_size=128)
test_loss,test_acc=model.evaluate(x_test,y_test)
print('mat mat:', test_loss)
print('Do chinh xac:', test_acc)
##################################################
# Out:
# (50000, 32, 32, 3)
# (50000, 1)
# (10000, 32, 32, 3)
# (10000, 1)
# So:  [8]
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_16 (Dense)            (None, 4000)              12292000
#
#  dense_17 (Dense)            (None, 1000)              4001000
#
#  dense_18 (Dense)            (None, 500)               500500
#
#  dense_19 (Dense)            (None, 10)                5010
#
# ...
# Total params: 16,798,510
# Trainable params: 16,798,510
# Non-trainable params: 0
# _________________________________________________________________
# (50000, 3072)
# (10000, 3072)
# (50000, 10)
# (10000, 10)
# Epoch 1/10
# 391/391 [==============================] - 184s 468ms/step - loss: 2.1753 - accuracy: 0.2575
# Epoch 2/10
# 391/391 [==============================] - 176s 450ms/step - loss: 1.8057 - accuracy: 0.3489
# Epoch 3/10
# ...

# %%
model.save('test1.h5')
